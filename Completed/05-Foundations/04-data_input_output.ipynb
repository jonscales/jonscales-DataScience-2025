# %% [markdown]
# <a href="https://colab.research.google.com/github/jonscales/jonscales-DataScience-2025/blob/main/Completed/05-Foundations/04-data_input_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 04 - Data Input and Output
#
# Most of data science is about **loading data, exploring it, and saving results**.
# In this notebook you will learn:
# - Reading CSV files with Pandas
# - Inspecting DataFrames (`head`, `info`, `describe`)
# - Writing data back to CSV
# - Reading Excel files (if available)

# %% [markdown]
# ## 1. Reading CSV Files

# %%
import pandas as pd

# Create a small CSV for demo
data = """Name,Age,Score
Alice,23,90
Bob,25,85
Charlie,22,95
"""
with open("students.csv", "w") as f:
    f.write(data)

# Read CSV into DataFrame
df = pd.read_csv("students.csv")
df
# Out:
#       Name  Age  Score
# 0    Alice   23     90
# 1      Bob   25     85
# 2  Charlie   22     95

# %% [markdown]
# ✅ **Your Turn**: Create your own small CSV (3–5 rows) and read it into Pandas.

# %%
# pandas
import pandas as pd

pets = """Name,Breed,Age
Cammy,Standard Poodle,7
Maximillian,Labradoodle,3
Nzinga,Pitbull/Coonhound,9
Peanut,Corgi,7
Pierre,Chocolate Lab,12
Dobby,Chihuahua,12
Smeagal,Orange Tabby,14
Thomas,Tuxedo,13
Athena,cat,14
Ashley,Russian Blue,6
"""
with open ("pets.csv", "w") as f:
    f.write(pets)

df = pd.read_csv("pets.csv")
df
# Out:
#           Name              Breed  Age
# 0        Cammy    Standard Poodle    7
# 1  Maximillian        Labradoodle    3
# 2       Nzinga  Pitbull/Coonhound    9
# 3       Peanut              Corgi    7
# 4       Pierre      Chocolate Lab   12
# 5        Dobby          Chihuahua   12
# 6      Smeagal       Orange Tabby   14
# 7       Thomas             Tuxedo   13
# 8       Athena                cat   14
# 9       Ashley       Russian Blue    6

# %% [markdown]
# ## 2. Exploring DataFrames

# %%
# Look at the first rows
df.head()
# Out:
#           Name              Breed  Age
# 0        Cammy    Standard Poodle    7
# 1  Maximillian        Labradoodle    3
# 2       Nzinga  Pitbull/Coonhound    9
# 3       Peanut              Corgi    7
# 4       Pierre      Chocolate Lab   12

# %%
# Info about columns and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Breed   10 non-null     object
#  2   Age     10 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
# Summary statistics
df.describe()
# Out:
#              Age
# count  10.000000
# mean    9.700000
# std     3.831159
# min     3.000000
# 25%     7.000000
# 50%    10.500000
# 75%    12.750000
# max    14.000000

# %% [markdown]
# ✅ **Your Turn**: Use `.head()` to preview your dataset and `.describe()` to see basic statistics.

# %%
# manipulating data frame (df)   head
df.head(3)
# Out:
#           Name              Breed  Age
# 0        Cammy    Standard Poodle    7
# 1  Maximillian        Labradoodle    3
# 2       Nzinga  Pitbull/Coonhound    9

# %%
# manipulating data frame  describe
df.describe().round(2)
# Out:
#          Age
# count  10.00
# mean    9.70
# std     3.83
# min     3.00
# 25%     7.00
# 50%    10.50
# 75%    12.75
# max    14.00

# %% [markdown]
# ## 3. Writing CSV Files

# %%
# Save the DataFrame to a new CSV
df.to_csv("students_copy.csv", index=False)
# %ls *.csv

# %% [markdown]
# ✅ **Your Turn**: Save your DataFrame to a CSV file called `my_data.csv`.

# %%
# writing a csv file from dataframe

df.to_csv("my_data.csv", index=False)
# %ls *.csv
# Out:
# my_data.csv  pets_copy.csv  pets.csv  students.csv

# %% [markdown]
# ## 4. Reading Excel Files

# %%
# Optional: Requires 'openpyxl' installed
# Save to Excel
df=pd.read_csv("students.csv")

df.to_excel("students.xlsx", index=False)

# Read Excel file
pd.read_excel("students.xlsx")
# Out:
#       Name  Age  Score
# 0    Alice   23     90
# 1      Bob   25     85
# 2  Charlie   22     95

# %% [markdown]
# ✅ **Your Turn**: Try saving your dataset to Excel and reading it back (if supported in your environment).

# %%
# saving csv as excel
dr=pd.read_csv("pets.csv")

dr.to_excel("pets.xlsx", index=False)

pd.read_excel("pets.xlsx")
# Out:
#           Name              Breed  Age
# 0        Cammy    Standard Poodle    7
# 1  Maximillian        Labradoodle    3
# 2       Nzinga  Pitbull/Coonhound    9
# 3       Peanut              Corgi    7
# 4       Pierre      Chocolate Lab   12
# 5        Dobby          Chihuahua   12
# 6      Smeagal       Orange Tabby   14
# 7       Thomas             Tuxedo   13
# 8       Athena                cat   14
# 9       Ashley       Russian Blue    6

# %% [markdown]
# ---
# ### Summary
# - `pd.read_csv` loads data into a DataFrame.
# - Use `.head()`, `.info()`, `.describe()` to explore quickly.
# - `df.to_csv` and `df.to_excel` save results.
# - Pandas makes file I/O simple and reliable.
