# %% [markdown]
# <a href="https://colab.research.google.com/github/jonscales/jonscales-DataScience-2025/blob/main/Completed/05-Foundations/06-jupyter_shortcuts_and_productivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⚡ 06 - Jupyter Shortcuts and Productivity
#
# Jupyter notebooks have **keyboard shortcuts and tricks** that make you faster.
# In this notebook you will learn:
# - Command vs. Edit mode
# - Essential keyboard shortcuts
# - Saving and exporting notebooks
# - Using `%history` and `%save`

# %% [markdown]
# ## 1. Modes in Jupyter

# %% [markdown]
# - **Edit mode** (green border, type in cell)
# - **Command mode** (blue border, issue commands on the notebook)
#
# Switch:
# - Press `Enter` → Edit mode
# - Press `Esc` → Command mode

# %% [markdown]
# ✅ **Your Turn**: Try switching between Edit and Command mode and notice the border color.

# %%
# %%markdown
# ##These mode change commands/shortcuts work in jupyter, but not in colab apparently.
# Out:
# ##These mode change commands/shortcuts work in jupyter, but not in colab apparently.

# %% [markdown]
# ## 2. Common Shortcuts

# %% [markdown]
# - `A` → Insert cell Above
# - `B` → Insert cell Below
# - `D D` → Delete a cell
# - `M` → Change to Markdown cell
# - `Y` → Change to Code cell
# - `Shift + Enter` → Run cell and move to next
# - `Ctrl + Enter` → Run cell, stay put
# - `Alt + Enter` → Run cell and insert new one below

# %% [markdown]
# ✅ **Your Turn**: Practice creating, deleting, and changing cell types using only shortcuts.

# %%
# %%markdown
# # control + M M opens a text cell  or markdown cell
# # contol + M Y returns cell to code cell
# Out:
# # control + M M opens a text cell  or markdown cell
# # contol + M Y returns cell to code cell

# %%
# %%markdown
# # control + M A opens a new code cell above current cell position
# Out:
# # control + M A opens a new code cell above current cell position

# %%
# %%markdown
# #control + M B opens a new code cell below current cell position
# Out:
# #control + M B opens a new code cell below current cell position

# %% [markdown]
# ## 3. Saving and Exporting

# %% [markdown]
# - `Ctrl + S` (or `Cmd + S` on Mac) → Save notebook
# - Menu: *File → Download as…* → export to `.py`, `.html`, or `.pdf`
# - GitHub + Colab workflow: commit changes back to your repo directly

# %% [markdown]
# ✅ **Your Turn**: Save this notebook, then try exporting to `.py` or `.html` from the File menu.

# %% [markdown]
# ## 4. History and Saving Code

# %%
# %history -n 1-5  # Show the first 5 commands in this session
# Out:
#    1: %history -n 1-5  # Show the first 5 commands in this session

# %%
# Save history to a file
# %save my_session.py 1-5
# Out:
# The following commands were written to file `my_session.py`:
# get_ipython().run_line_magic('history', '-n 1-5  # Show the first 5 commands in this session')
# # Save history to a file
# get_ipython().run_line_magic('save', 'my_session.py 1-5')

# %% [markdown]
# ✅ **Your Turn**: Use `%history` to view the last 10 commands you ran, then save them to `last10.py`.

# %%
# history command
# %history -n


#%save last10.py
# Out:
#    1: %history -n 1-5  # Show the first 5 commands in this session
#    2:
# # Save history to a file
# %save my_session.py 1-5
#    3:
# # history command
# %history -n -10
#    4:
# # history command
# %history -n -10
#    5:
# # history command
# %history
#    6:
# %%markdown
# #control + M B opens a new code cell below current cell position
#    7:
# %%markdown
# # control + M A opens a new code cell above current cell position
#    8:
#
# %%markdown
# # control + M M opens a text cell  or markdown cell
# # contol + M Y returns cell to code cell
#    9:
# %%markdown
# ##These mode change commands/shortcuts work in jupyter, but not in colab apparently.
#   10:
# # history command
# %history
#   11:
# # history command
# %history
#
# %save last10.py
#   12:
# # history command
# %history -n -10
#
# #%save last10.py
#   13:
# # history command
# %history -n -10
#
# #%save last10.py
#   14:
# # history command
# %history -n -10:
#
# #%save last10.py
#   15:
# # history command
# %history -10
#
# #%save last10.py
#   16:
# # history command
# %history
#
# #%save last10.py
#   17:
# # history command
# %history -10:
#
#
# #%save last10.py
#   18:
# # history command
# %history 10:
#
#
# #%save last10.py
#   19:
# # history command
# %history -n :-10
#
#
# #%save last10.py
#   20:
# # history command
# %history -n :-10
#
#
# #%save last10.py
#   21:
# # history command
# %history -n :10
#
#
# #%save last10.py
#   22:
# # history command
# %history -n 10
#
#
# #%save last10.py
#   23:
# # history command
# %history -n 10
#
#
# #%save last10.py
#   24:
# # history command
# %history -n 20
#
#
# #%save last10.py
#   25:
# # history command
# %history -n 30
#
#
# #%save last10.py
#   26:
# # history command
# %history -n
#
#
# #%save last10.py

# %%
# %save last10.py
# Out:
# '' was not found in history, as a file, url, nor in the user namespace.

# %% [markdown]
# ---
# ### Summary
# - Command vs Edit mode controls how you interact with cells.
# - Shortcuts make notebook use much faster.
# - You can export notebooks to share or turn them into scripts.
# - `%history` and `%save` help you capture your work.
