# %% [markdown]
# <a href="https://colab.research.google.com/github/jonscales/jonscales-DataScience-2025/blob/main/Completed/06-Working_with_Data_Adv/01-lists_dicts_and_tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Notebook 01: Lists, Dicts, Tuples, and Sets (Oh My!)
#
# Welcome, data tamer. Before we dance with DataFrames and juggle Series, we must revisit the sacred scrolls of Python's core data structures.
#
# In this notebook, you will:
# - Recap the mighty `list`, `dict`, `tuple`, and `set`
# - Learn what makes each special (besides being annoying to explain at parties)
# - Practice slicing, accessing, and modifying them
# - Build up intuition for working with structured data
#
# ---

# %% [markdown]
# ## 🧺 Lists
# `list`: Ordered, mutable, and basically the cargo pants of Python.

# %%
fruits = ["apple", "banana", "cherry", "dragonfruit"]
print("First fruit:", fruits[0])
print("Last fruit:", fruits[-1])

fruits.append("elderberry")
print("Updated list:", fruits)
# Out:
# First fruit: apple
# Last fruit: dragonfruit
# Updated list: ['apple', 'banana', 'cherry', 'dragonfruit', 'elderberry']

# %% [markdown]
# ## 🔐 Tuples
# `tuple`: Like lists, but committed — they don’t change. Perfect for fixed data.

# %%
coordinates = (34.05, -118.25)  # Latitude, Longitude
print("Coordinates:", coordinates)

# Uncomment this to see Python throw a tantrum
coordinates[0] = 0
# Out:
# Coordinates: (34.05, -118.25)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2290748006.py in <cell line: 0>()
#       3
#       4 # Uncomment this to see Python throw a tantrum
# ----> 5 coordinates[0] = 0
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## 📦 Dictionaries
# `dict`: Key-value pairs. Like JSON, but with fewer quotation marks and more sarcasm.

# %%
student = {
    "name": "Alice",
    "GPA": 3.9,
    "major": "Data Science"
}

print("Student name:", student["name"])
print("GPA using .get():", student.get("GPA"))

student["minor"] = "Philosophy"
print("Updated dictionary:", student)
# Out:
# Student name: Alice
# GPA using .get(): 3.9
# Updated dictionary: {'name': 'Alice', 'GPA': 3.9, 'major': 'Data Science', 'minor': 'Philosophy'}

# %% [markdown]
# ## 🎯 Sets
# `set`: Unordered, unique values only. Great for removing duplicates or doing cool mathy stuff.

# %%
courses = {"CS101", "CS102", "CS103", "CS101"}  # Duplicate ignored
print("Courses:", courses)

print("Is CS102 in the set?", "CS102" in courses)

courses.add("CS104")
courses.discard("CS101")
print("Modified courses:", courses)
# Out:
# Courses: {'CS103', 'CS102', 'CS101'}
# Is CS102 in the set? True
# Modified courses: {'CS103', 'CS102', 'CS104'}

# %% [markdown]
# ---
# ## 🧰 Your Turn
#
# 1. Create a list of your top 5 favorite foods. Print the last item using a negative index.
# 2. Create a dictionary that maps student names to GPA (be kind). Add a new student.
# 3. Make a tuple of the days of the week. Try to change one. Document what happens.
# 4. Create a `set` of course names. Add a duplicate. Reflect on how sets feel about duplicates.
#
# 🎯 **Bonus**: Use a list comprehension to build a list of all squares from 1–20.

# %%
from re import M
# Your brilliant code goes here!
from IPython.display import display, Markdown
# list
favfood =["bbq", "pecan pie", "chili", "fish&chips", "fajitas"]
print(favfood[-1])

#dictionary
studentGPAs = {
    "Bob":"2.8",
    "Pat":"3.9",
    "Roy":"3.4",
    "Joe":"3.2"
}

print("Original studentGPAs dictionary:",studentGPAs)
studentGPAs["Tom"]="3.5"
print("Updated studentGPAs:", studentGPAs)

# tuple
weekdays =("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")
print(weekdays)
display(Markdown("Tuples are immuttable, so if we try to add an 8th day to the week (tomorrow), it will trigger this error message"))
display(Markdown("---------------------------------------------------------------------------"))
display(Markdown("TypeError                                 Traceback (most recent call last)"))
display(Markdown("/tmp/ipython-input-3266970726.py in <cell line: 0>()"))
display(Markdown("     20 weekdays =('Monday', 'Tuesday','Wednesday', 'Thursday','Friday', 'Saturday', 'Sunday')"))
display(Markdown("     21 print(weekdays)"))
display(Markdown("---> 22 weekdays[8]='tomorrow'"))

display(Markdown("TypeError: 'tuple' object does not support item assignment"))
#weekdays[8]="tomorrow"

# sets
courses = {"Biol1114", "Biol1214", "Biol3334", "Biol4001", "Biol3144"}

print("Biol Course List:",courses)
print("Is CS102 a Biol course?", "CS102" in courses)
courses.add("Biol1114")

print("Modified courses:", courses)
display(Markdown("printing the set, prints the items in numerical order even if they were not originally entered in that order"))
display(Markdown("adding a duplicate caused the initial instance of the item to be removed "))
display(Markdown("and the newly added duplicate was placed at the end of the lsit, even thoough"))
display(Markdown("this made it out of numerical order"))
# Out:
# fajitas
# Original studentGPAs dictionary: {'Bob': '2.8', 'Pat': '3.9', 'Roy': '3.4', 'Joe': '3.2'}
# Updated studentGPAs: {'Bob': '2.8', 'Pat': '3.9', 'Roy': '3.4', 'Joe': '3.2', 'Tom': '3.5'}
# ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday')
# Tuples are immuttable, so if we try to add an 8th day to the week (tomorrow), it will trigger this error message
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3266970726.py in <cell line: 0>()
#      20 weekdays =('Monday', 'Tuesday','Wednesday', 'Thursday','Friday', 'Saturday', 'Sunday')
#      21 print(weekdays)
# ---> 22 weekdays[8]='tomorrow'
# TypeError: 'tuple' object does not support item assignment
# Biol Course List: {'Biol1214', 'Biol3334', 'Biol3144', 'Biol4001', 'Biol1114'}
# Is CS102 a Biol course? False
# Modified courses: {'Biol1214', 'Biol3334', 'Biol3144', 'Biol4001', 'Biol1114'}
# printing the set, prints the items in numerical order even if they were not originally entered in that order
# adding a duplicate caused the initial instance of the item to be removed
# and the newly added duplicate was placed at the end of the lsit, even thoough
# this made it out of numerical order

# %% [markdown]
# ---
# ## 🧼 Why This Matters
#
# Before we start feeding `.csv` files into Pandas like a malfunctioning vending machine, we need to truly *feel* how data is structured. These built-in types help shape, store, and manipulate everything we’ll touch from here on.
#
# Next up? Pandas `Series` and `DataFrames`. Buckle up.
