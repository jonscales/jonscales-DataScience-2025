# %% [markdown]
# <a href="https://colab.research.google.com/github/jonscales/jonscales-DataScience-2025/blob/main/Completed/06-Working_with_Data_Adv/04-indexing_and_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎯 Notebook 04: Indexing and Selection
#
# Time to slice and dice.
#
# In this notebook, you'll:
# - Use `.loc[]` for label-based selection
# - Use `.iloc[]` for position-based selection
# - Create boolean masks to filter rows
# - Select specific columns and rows (solo or together)
#
# Let the chaos of index manipulation begin.
# ---

# %%
import pandas as pd
import seaborn as sns

# We'll use the Titanic dataset again
df = sns.load_dataset("titanic")
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %% [markdown]
# ## 🔎 Select rows by label with `.loc[]`

# %%
# .loc[row_label, column_label]
# Titanic uses default RangeIndex, so labels are integers
print(df.loc[0])

# Row range (inclusive!)
df.loc[0:4, ["age", "fare", "sex"]]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object
#     age     fare     sex
# 0  22.0   7.2500    male
# 1  38.0  71.2833  female
# 2  26.0   7.9250  female
# 3  35.0  53.1000  female
# 4  35.0   8.0500    male

# %% [markdown]
# ## 🔢 Select rows by position with `.iloc[]`

# %%
# iloc uses pure positions
df.iloc[0]  # First row

# Row slice, column slice
df.iloc[1:4, 0:5]
# Out:
#    survived  pclass     sex   age  sibsp
# 1         1       1  female  38.0      1
# 2         1       3  female  26.0      0
# 3         1       1  female  35.0      1

# %% [markdown]
# ## 🎯 Boolean Masking (Filtering)

# %%
# Filter passengers under age 10
kids = df[df["age"] < 10]
kids[["age", "sex", "class"]].head()
# Out:
#     age     sex   class
# 7   2.0    male   Third
# 10  4.0  female   Third
# 16  2.0    male   Third
# 24  8.0  female   Third
# 43  3.0  female  Second

# %% [markdown]
# ## 🧠 Compound Conditions

# %%
# Adults in First Class who paid over $100
rich_folks = df[(df["age"] > 18) & (df["class"] == "First") & (df["fare"] > 100)]
rich_folks[["age", "class", "fare"]].head()
# Out:
#       age  class      fare
# 27   19.0  First  263.0000
# 88   23.0  First  263.0000
# 118  24.0  First  247.5208
# 195  58.0  First  146.5208
# 215  31.0  First  113.2750

# %% [markdown]
# ## 🧹 Select Columns Only

# %%
df[["sex", "age", "embarked"]].head()
# Out:
#       sex   age embarked
# 0    male  22.0        S
# 1  female  38.0        C
# 2  female  26.0        S
# 3  female  35.0        S
# 4    male  35.0        S

# %% [markdown]
# ## 🎯 Your Turn
#
# 1. Select the first row using `.iloc[]`, then again using `.loc[]`.
# 2. Slice the first 5 rows and select only `survived`, `sex`, and `age` columns.
# 3. Filter the dataset for female passengers over 40.
# 4. Create a DataFrame of passengers in 2nd class under age 15.
# 5. Use `.loc[]` to select the rows 10–20 and only the columns `fare`, `class`, and `age`.
#
# 🎯 **Bonus:** Find passengers with missing `age` and print only their `name`, `age`, and `pclass` (use `.isnull()`).

# %%
# Your slicing magic goes here!
import pandas as pd
import seaborn as sns
df = sns.load_dataset("titanic")

# using .iloc[]
df.iloc[0]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
# .loc[]
df.loc[0]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
# slicing

df.loc[0:4, ["survived", "age","sex"]]
# Out:
#    survived   age     sex
# 0         0  22.0    male
# 1         1  38.0  female
# 2         1  26.0  female
# 3         1  35.0  female
# 4         0  35.0    male

# %%
# cougars
cougars = df[(df["age"] > 40) & (df["sex"]=="female")]
cougars.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 52          1       1  female  49.0      1      0  76.7292        C   First
# 132         0       3  female  47.0      1      0  14.5000        S   Third
# 167         0       3  female  45.0      1      4  27.9000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 11   woman       False    C  Southampton   yes   True
# 15   woman       False  NaN  Southampton   yes   True
# 52   woman       False    D    Cherbourg   yes  False
# 132  woman       False  NaN  Southampton    no  False
# 167  woman       False  NaN  Southampton    no  False

# %%
# minors in second class

minors = df[(df["age"] < 15) & (df["class"]=="Second")]
print(minors.describe())
#minors.info()
minors
# Out:
#        survived  pclass        age      sibsp      parch       fare
# count      19.0    19.0  19.000000  19.000000  19.000000  19.000000
# mean        1.0     2.0   4.543684   0.789474   1.263158  28.323905
# std         0.0     0.0   3.955098   0.630604   0.561951   7.750054
# min         1.0     2.0   0.670000   0.000000   0.000000  14.500000
# 25%         1.0     2.0   1.500000   0.000000   1.000000  24.500000
# 50%         1.0     2.0   3.000000   1.000000   1.000000  26.250000
# 75%         1.0     2.0   6.500000   1.000000   2.000000  34.875000
# max         1.0     2.0  14.000000   2.000000   2.000000  41.579200
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 9           1       2  female  14.00      1      0  30.0708        C  Second
# 43          1       2  female   3.00      1      2  41.5792        C  Second
# 58          1       2  female   5.00      1      2  27.7500        S  Second
# 78          1       2    male   0.83      0      2  29.0000        S  Second
# 183         1       2    male   1.00      2      1  39.0000        S  Second
# 193         1       2    male   3.00      1      1  26.0000        S  Second
# 237         1       2  female   8.00      0      2  26.2500        S  Second
# 340         1       2    male   2.00      1      1  26.0000        S  Second
# 407         1       2    male   3.00      1      1  18.7500        S  Second
# 446         1       2  female  13.00      0      1  19.5000        S  Second
# 530         1       2  female   2.00      1      1  26.0000        S  Second
# 535         1       2  female   7.00      0      2  26.2500        S  Second
# 549         1       2    male   8.00      1      1  36.7500        S  Second
# 618         1       2  female   4.00      2      1  39.0000        S  Second
# 720         1       2  female   6.00      0      1  33.0000        S  Second
# 750         1       2  female   4.00      1      1  23.0000        S  Second
# 755         1       2    male   0.67      1      1  14.5000        S  Second
# 827         1       2    male   1.00      0      2  37.0042        C  Second
# 831         1       2    male   0.83      1      1  18.7500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 9    child       False  NaN    Cherbourg   yes  False
# 43   child       False  NaN    Cherbourg   yes  False
# 58   child       False  NaN  Southampton   yes  False
# 78   child       False  NaN  Southampton   yes  False
# 183  child       False    F  Southampton   yes  False
# 193  child       False    F  Southampton   yes  False
# 237  child       False  NaN  Southampton   yes  False
# 340  child       False    F  Southampton   yes  False
# 407  child       False  NaN  Southampton   yes  False
# 446  child       False  NaN  Southampton   yes  False
# 530  child       False  NaN  Southampton   yes  False
# 535  child       False  NaN  Southampton   yes  False
# 549  child       False  NaN  Southampton   yes  False
# 618  child       False    F  Southampton   yes  False
# 720  child       False  NaN  Southampton   yes  False
# 750  child       False  NaN  Southampton   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 827  child       False  NaN    Cherbourg   yes  False
# 831  child       False  NaN  Southampton   yes  False

# %%
# treasure hunt rows 10-20 and columns  fare, class, and age

df.loc[10:20, ["fare", "class", "age"]]
# Out:
#        fare   class   age
# 10  16.7000   Third   4.0
# 11  26.5500   First  58.0
# 12   8.0500   Third  20.0
# 13  31.2750   Third  39.0
# 14   7.8542   Third  14.0
# 15  16.0000  Second  55.0
# 16  29.1250   Third   2.0
# 17  13.0000  Second   NaN
# 18  18.0000   Third  31.0
# 19   7.2250   Third   NaN
# 20  26.0000  Second  35.0

# %%
#missing age and print only their name, age, and pclass (use .isnull()).
ageless = df[df["age"].isnull()]
print(ageless.describe())

ageless[["sex", "age", "pclass"]].head(10)
# Out:
#          survived      pclass  age       sibsp       parch        fare
# count  177.000000  177.000000  0.0  177.000000  177.000000  177.000000
# mean     0.293785    2.598870  NaN    0.564972    0.180791   22.158567
# std      0.456787    0.763216  NaN    1.626316    0.534145   31.874608
# min      0.000000    1.000000  NaN    0.000000    0.000000    0.000000
# 25%      0.000000    3.000000  NaN    0.000000    0.000000    7.750000
# 50%      0.000000    3.000000  NaN    0.000000    0.000000    8.050000
# 75%      1.000000    3.000000  NaN    0.000000    0.000000   24.150000
# max      1.000000    3.000000  NaN    8.000000    2.000000  227.525000
#        sex  age  pclass
# 5     male  NaN       3
# 17    male  NaN       2
# 19  female  NaN       3
# 26    male  NaN       3
# 28  female  NaN       3
# 29    male  NaN       3
# 31  female  NaN       1
# 32  female  NaN       3
# 36    male  NaN       3
# 42    male  NaN       3

# %% [markdown]
# ---
# ## 🧼 Why This Matters
#
# Being able to surgically select parts of your dataset is the core of real analysis. Whether you're cleaning junk or feeding a model, proper indexing = power.
#
# Next: cleaning your data with `.dropna()`, `.fillna()`, and more. The fun begins when you try to fix the stuff that's broken.
