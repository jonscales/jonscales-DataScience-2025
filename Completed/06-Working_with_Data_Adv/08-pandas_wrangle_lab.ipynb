# %% [markdown]
# <a href="https://colab.research.google.com/github/jonscales/jonscales-DataScience-2025/blob/main/Completed/06-Working_with_Data_Adv/08-pandas_wrangle_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧪 Pandas Wrangle Lab: Clean & Explore a Real Dataset
#
# ## 🔹 LEARNING GOALS:
# - Practice loading, cleaning, and exploring real-world data
# - Apply column creation, renaming, sorting, and filtering
# - Use `.info()`, `.describe()`, and `.query()` fluently

# %% [markdown]
# ### 📥 1. Load the Dataset

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/jonscales/jonscales-DataScience-2025/main/data/students.csv"
df = pd.read_csv(url)
df
# Out:
#      first_name  last_name  math_score  science_score
# 0      Danielle       Wood         100             95
# 1         Angel      Clark          67             78
# 2        Joshua      Adams          61            100
# 3       Jeffrey     Zuniga          77             99
# 4          Jill       Wong          75             83
# 5         Erica      Lynch          74             96
# 6      Patricia    Jackson          68             72
# 7   Christopher     Daniel          66             64
# 8        Robert     Martin          94             62
# 9       Anthony       Gray          65             74
# 10      Jeffery       Mayo          97             78
# 11      William     Bowman          87             65
# 12      Anthony    Hawkins          62             74
# 13        James      Cohen          61             66
# 14        Debra    Cameron          65             84
# 15          Amy    Parsons          73             77
# 16      Jeffrey      Perez          74             89
# 17      Bridget    Johnson          92            100
# 18         Lisa    Stewart          98             83
# 19         Adam      Adams          61             70
# 20        Linda      Clark          95             83
# 21        Helen       Hahn          72             82
# 22      Matthew     Walter          94             73
# 23         Eric    Edwards          86             77
# 24        Susan       Rios          74             64
# 25      Matthew     Foster          88             98
# 26  Christopher      Rocha          97            100
# 27        Colin      Ellis          77             70
# 28      Melanie      Baker          60             94
# 29    Cassandra     Wright          70             75
# 30      Lindsay    Hoffman          87             70
# 31      Jessica      Baker          81             89
# 32       Amanda   Richards          77             84
# 33       Teresa      Hurst          69             77
# 34     Nicholas       Ross          73            100
# 35       Andrea   Robinson          81             95
# 36        Maria     Bright          66             74
# 37    Christine      Hicks          65             80
# 38     Michelle      Davis          84             63
# 39      Barbara   Williams          66             74
# 40        Janet  Rodriguez          82             62
# 41      Brandon     Burton          82             80
# 42       Jeremy     Conner          98             85
# 43        Keith  Henderson          76             77
# 44  Christopher      Brown          62             64
# 45        Jesse      James          89             73
# 46        Craig    Ferrell          94             96
# 47       Joshua       Rice          67             80
# 48      Cynthia     Maddox          84             73
# 49      Michael   Valencia          65             91

# %% [markdown]
# ### 🔎 2. Inspect and Audit the Data

# %%
# Basic overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     50 non-null     object
#  1   last_name      50 non-null     object
#  2   math_score     50 non-null     int64
#  3   science_score  50 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.7+ KB

# %%
# Summary stats
df.describe()
# Out:
#        math_score  science_score
# count    50.00000      50.000000
# mean     77.56000      80.240000
# std      12.17753      11.659384
# min      60.00000      62.000000
# 25%      66.25000      73.000000
# 50%      75.50000      78.000000
# 75%      87.00000      89.000000
# max     100.00000     100.000000

# %% [markdown]
# ### 🧼 3. Clean Missing or Invalid Data

# %%
# Check for missing values
df.isnull().sum()
# Out:
# first_name       0
# last_name        0
# math_score       0
# science_score    0
# dtype: int64

# %%
# Drop rows with missing names
df.dropna(subset=["first_name", "last_name"], inplace=True)

# Fill any missing scores with column average
df["math_score"].fillna(df["math_score"].mean(), inplace=True)
df["science_score"].fillna(df["science_score"].mean(), inplace=True)
# Out:
# /tmp/ipython-input-210016614.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["math_score"].fillna(df["math_score"].mean(), inplace=True)
# /tmp/ipython-input-210016614.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["science_score"].fillna(df["science_score"].mean(), inplace=True)

# %% [markdown]
# ### 🧠 4. Feature Engineering (New Columns)

# %%
# Add average and grade
df["average_score"] = (df["math_score"] + df["science_score"]) / 2

def grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    else:
        return "D"

df["grade"] = df["average_score"].apply(grade)
df.head()
# Out:
#   first_name last_name  math_score  science_score  average_score grade
# 0   Danielle      Wood         100             95           97.5     A
# 1      Angel     Clark          67             78           72.5     C
# 2     Joshua     Adams          61            100           80.5     B
# 3    Jeffrey    Zuniga          77             99           88.0     B
# 4       Jill      Wong          75             83           79.0     C

# %% [markdown]
# ### 🔽 5. Sorting and Filtering

# %%
# Top performers
df[df["average_score"] > 90].sort_values(by="average_score", ascending=False).head()
# Out:
#      first_name last_name  math_score  science_score  average_score grade
# 26  Christopher     Rocha          97            100           98.5     A
# 0      Danielle      Wood         100             95           97.5     A
# 17      Bridget   Johnson          92            100           96.0     A
# 46        Craig   Ferrell          94             96           95.0     A
# 25      Matthew    Foster          88             98           93.0     A

# %% [markdown]
# ### 📊 6. Group and Describe by Grade

# %%
# How many of each grade?
df["grade"].value_counts()
# Out:
# grade
# C    22
# B    14
# A     7
# D     7
# Name: count, dtype: int64

# %%
# Average scores per grade group
df.groupby("grade")[["math_score", "science_score", "average_score"]].mean()
# Out:
#        math_score  science_score  average_score
# grade
# A       95.285714      93.857143      94.571429
# B       81.500000      86.857143      84.178571
# C       73.590909      75.590909      74.590909
# D       64.428571      68.000000      66.214286

# %% [markdown]
# ### 💾 7. Save the Cleaned Dataset

# %%
df.to_csv("student_scores_cleaned.csv", index=False)

# %% [markdown]
# ### 🧠 Challenge Task
#
# > Your turn! Filter out students who got a D, sort by last name, and export to a new file:
# - Only include columns: `first_name`, `last_name`, `grade`
# - Save it as `"d_students.csv"`

# %%
import pandas as pd

df=pd.read_csv("student_scores_cleaned.csv")
df.head()
# Out:
#   first_name last_name  math_score  science_score  average_score grade
# 0   Danielle      Wood         100             95           97.5     A
# 1      Angel     Clark          67             78           72.5     C
# 2     Joshua     Adams          61            100           80.5     B
# 3    Jeffrey    Zuniga          77             99           88.0     B
# 4       Jill      Wong          75             83           79.0     C

# %%
# drop individual course scores
df.drop(columns=["math_score", "science_score", "average_score"], inplace=True)
df.head()
# Out:
#   first_name last_name grade
# 0   Danielle      Wood     A
# 1      Angel     Clark     C
# 2     Joshua     Adams     B
# 3    Jeffrey    Zuniga     B
# 4       Jill      Wong     C

# %%
# remove D students
dfnoD = df[df["grade"] != "D"]
dfnoD.head()
dfnoD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  43 non-null     object
#  1   last_name   43 non-null     object
#  2   grade       43 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
# save no D dataframe

dfnoD.to_csv("d_students.csv", index=False)

# %% [markdown]
# ### 📝 Summary
#
# This lab gave you hands-on experience with:
# - Cleaning nulls and type mismatches
# - Creating new columns
# - Filtering and sorting real data
# - Grouping and summarizing by categorical features
#
# Your data wrangling toolbox is now ready for real-world messiness. 🧹🛠️
